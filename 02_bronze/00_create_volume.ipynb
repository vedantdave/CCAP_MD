# %%
spark.sql("""
SHOW VOLUMES IN ccap_md.bronze
""").show()

# %%
spark.sql("""
CREATE VOLUME IF NOT EXISTS ccap_md.bronze.source_files
""")

# %%
spark.sql("""
SHOW VOLUMES IN ccap_md.bronze
""").show()
